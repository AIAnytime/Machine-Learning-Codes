# %%
import pandas as pd
import numpy as np

# %%
mydata=pd.read_csv(r"C:\Users\pawan\Desktop\datanew\ipl\match.csv")

# %%
mydata
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
mydata.shape
# Out:
# (637, 17)

# %%
mydata.keys
# Out:
# <bound method NDFrame.keys of      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# ...

# %%
newdata=mydata.replace(['Royal Challengers Bangalore', 'Kolkata Knight Riders', 'Kings XI Punjab', 'Chennai Super Kings', 'Delhi Daredevils','Rajasthan Royals','Mumbai Indians','Deccan Chargers','Gujarat Lions','Sunrisers Hyderabad','Rising Pune Supergiants','Kochi Tuskers Kerala','Pune Warriors'],['RCB','KKR','KXIP','CSK','DD','RR','MI','DC','GL','SRH','RPS','KTK','PW'])

# %%
newdata
# Out:
#      Match_SK  match_id Team1 Team2 match_date  Season_Year  \
# 0           0    335987   RCB   KKR  4/18/2008         2008
# 1           1    335988  KXIP   CSK  4/19/2008         2008
# 2           2    335989    DD    RR  4/19/2008         2008
# 3           3    335990    MI   RCB  4/20/2008         2008
# 4           4    335991   KKR    DC  4/20/2008         2008
# 5           5    335992    RR  KXIP  4/21/2008         2008
# 6           6    335993    DC    DD  4/22/2008         2008
# 7           7    335994   CSK    MI  4/23/2008         2008
# 8           8    335995    DC    RR  4/24/2008         2008
# 9           9    335996  KXIP    MI  4/25/2008         2008
# 10         10    335997   RCB    RR  4/26/2008         2008
# 11         11    335998   CSK   KKR  4/26/2008         2008
# 12         12    335999    MI    DC  4/27/2008         2008
# 13         13    336000  KXIP    DD  4/27/2008         2008
# 14         14    336001   RCB   CSK  4/28/2008         2008
# ...

# %%
encode = {'Team1': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'Team2': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'Toss_Winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'match_winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'Draw':14}}
newdata.replace(encode, inplace=True)

# %%
newdata
# Out:
#      Match_SK  match_id  Team1  Team2 match_date  Season_Year  \
# 0           0    335987      3      2  4/18/2008         2008
# 1           1    335988      9      5  4/19/2008         2008
# 2           2    335989      7      6  4/19/2008         2008
# 3           3    335990      1      3  4/20/2008         2008
# 4           4    335991      2      4  4/20/2008         2008
# 5           5    335992      6      9  4/21/2008         2008
# 6           6    335993      4      7  4/22/2008         2008
# 7           7    335994      5      1  4/23/2008         2008
# 8           8    335995      4      6  4/24/2008         2008
# 9           9    335996      9      1  4/25/2008         2008
# 10         10    335997      3      6  4/26/2008         2008
# 11         11    335998      5      2  4/26/2008         2008
# 12         12    335999      1      4  4/27/2008         2008
# 13         13    336000      9      7  4/27/2008         2008
# ...

# %%
target=newdata["match_winner"]

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
type(newdata)
# Out:
# pandas.core.frame.DataFrame

# %%
x_in=target.values.reshape(len(feature),6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f1b49e5d840e> in <module>()
# ----> 1 x_in=target.values.reshape(len(feature),6)
#
# ValueError: cannot reshape array of size 637 into shape (637,6)

# %%
y_out=target.values.reshape(len(target),1)

# %%
x_in.shape
# Out:
# (637, 6)

# %%
y_out.shape
# Out:
# (637, 1)

# %%
x_in
# Out:
# array([['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#         'M Chinnaswamy Stadium', 'Royal Challengers Bangalore',
#         'Kolkata Knight Riders', 'field'],
#        ['Kings XI Punjab', 'Chennai Super Kings',
#         'Punjab Cricket Association Stadium, Mohali',
#         'Chennai Super Kings', 'Chennai Super Kings', 'bat'],
#        ['Delhi Daredevils', 'Rajasthan Royals', 'Feroz Shah Kotla',
#         'Rajasthan Royals', 'Delhi Daredevils', 'bat'],
#        ...,
#        ['Sunrisers Hyderabad', 'Kolkata Knight Riders',
#         'M Chinnaswamy Stadium', 'Kolkata Knight Riders',
#         'Kolkata Knight Riders', 'Field'],
#        ['Mumbai Indians', 'Kolkata Knight Riders',
#         'M Chinnaswamy Stadium', 'Mumbai Indians', 'Mumbai Indians',
#         'Field'],
#        ['Mumbai Indians', 'Rising Pune Supergiants',
#         'Rajiv Gandhi International Stadium Uppal', 'Mumbai Indians',
#         'Mumbai Indians', 'Bat']], dtype=object)

# %%
xtrain=x_in[:-191]
xtest=x_in[-191:]
ytrain=y_out[:-191]
ytest=y_out[-191:]

# %%
xtrain.shape
# Out:
# (446, 5)

# %%
xtest.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-102e0ab1ba36> in <module>()
# ----> 1 xtest.shape
#
# NameError: name 'xtest' is not defined
